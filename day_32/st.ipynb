# %%
pip install ydata-profiling streamlit
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install undetected-chromedriver selenium pandas openpyxl
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for undetected-chromedriver: filename=undetected_chromedriver-3.5.5-py3-none-any.whl size=47184 sha256=30cab0d8dce8a3381cf89b9246f7e056987264698559966007ca8deeec277c7a
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\cf\a1\db\e1275b6f7259aacd6b045f8bfcb1fcbc93827a3916ba55d5b7
# Successfully built undetected-chromedriver
# ...
# Note: you may need to restart the kernel to use updated packages.
