# %%
# in traditional programming we give data to machine and give rules and it gives output
# in machine learning we give data and output and it gives rules 
# in machine learning most general formula is y = 2x-1
# if x=10 then y must be 19 but neural network will put formulas on it and give more accuracy 
# desne is the number of layers in the neural network
# optimizers are used to minimize the loss it give us result
# loss function used to give us guess 
# SGd is the stochastic gradient descent
# mean squared error is used to calculate the loss 
# epochs is the number of iterations

# %%
import pandas as pd 
import tensorflow as tf
from tensorflow import keras
import numpy as np

# %%
import numpy as np 
import tensorflow as tf 
from tensorflow import keras

# %%
# making the simplest sequential layer neural network 

model = keras.Sequential([keras.layers.Dense(units=1,input_shape=[1])])
model.compile(optimizer='sgd',loss='mean_squared_error')
# making numpy arrays
xs = np.array([-1.0,0.0,1.0,2.0,3.0,4.0],dtype=float)
ys = np.array([-3.0,-1.0,0.0,3.0,5.0,7.0],dtype=float)
# training the model
model.fit(xs,ys,epochs=100)
# Out:
# c:\Users\HP\miniconda3\envs\tf_env\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 0.9783
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 536ms/step - loss: 0.9607
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 726ms/step - loss: 0.9436
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 563ms/step - loss: 0.9268
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step - loss: 0.9105
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 403ms/step - loss: 0.8945
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step - loss: 0.8788
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - loss: 0.8635
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step - loss: 0.8485
# Epoch 10/100
# ...

# %%
# predicting the value 
print(model.predict(np.array([10.0])))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step
# [[18.11881]]
