# %% [markdown]
# # Best model selection

# %%
import pandas as pd 
import  seaborn as sns 
import matplotlib.pyplot as plt 
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

# %%
df = pd.read_csv("C:\\Users\\HP\\Desktop\\SaudiNov2022data.csv")
df
# Out:
#            date  Unnamed: 1  cummlative cases  Death   Recoverd   \
# 0    02/03/2020           1                 1       0          0
# 1    03/03/2020           2                 1       0          0
# 2    04/03/2020           3                 2       0          0
# 3    05/03/2020           4                 5       0          0
# 4    06/03/2020           5                 5       0          0
# ..          ...         ...               ...     ...        ...
# 957  15/10/2022         958            818837    9381     805463
# 958  16/10/2022         959            819083    9383     805670
# 959  17/10/2022         960            819323    9384     805851
# 960  18/10/2022         961            819570    9387     806046
# 961  19/10/2022         962            819811    9390     806237
#
#      Active cases   Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 0                1         NaN         NaN         NaN         NaN
# 1                1         NaN         NaN         NaN         NaN
# 2                2         NaN         NaN         NaN         NaN
# 3                5         NaN         NaN         NaN         NaN
# 4                5         NaN         NaN         NaN         NaN
# ..             ...         ...         ...         ...         ...
# 957           3993         NaN         NaN         NaN         NaN
# 958           4030         NaN         NaN         NaN         NaN
# 959           4088         NaN         NaN         NaN         NaN
# 960           4137         NaN         NaN         NaN         NaN
# 961           4184         NaN         NaN         NaN         NaN
#
#      Unnamed: 10  Unnamed: 11  Unnamed: 12 Unnamed: 13
# 0            NaN          NaN          NaN         NaN
# 1            NaN          NaN          NaN         NaN
# 2            NaN          NaN          NaN         NaN
# 3            NaN          NaN          NaN         NaN
# 4            NaN          NaN          NaN         NaN
# ..           ...          ...          ...         ...
# 957          NaN          NaN          NaN         NaN
# 958          NaN          NaN          NaN         NaN
# 959          NaN          NaN          NaN         NaN
# 960          NaN          NaN          NaN         NaN
# 961          NaN          NaN          NaN         NaN
#
# [962 rows x 14 columns]

# %%
df.head(100)
# Out:
#           date  Unnamed: 1  cummlative cases  Death   Recoverd   \
# 0   02/03/2020           1                 1       0          0
# 1   03/03/2020           2                 1       0          0
# 2   04/03/2020           3                 2       0          0
# 3   05/03/2020           4                 5       0          0
# 4   06/03/2020           5                 5       0          0
# ..         ...         ...               ...     ...        ...
# 95  05/06/2020          96             98869     676      71791
# 96  06/06/2020          97            101914     712      72817
# 97  07/06/2020          98            105283     746      74524
# 98  08/06/2020          99            108571     783      76339
# 99  09/06/2020         100            112288     819      77954
#
#     Active cases   Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 0               1         NaN         NaN         NaN         NaN
# 1               1         NaN         NaN         NaN         NaN
# 2               2         NaN         NaN         NaN         NaN
# 3               5         NaN         NaN         NaN         NaN
# 4               5         NaN         NaN         NaN         NaN
# ..            ...         ...         ...         ...         ...
# 95          26402         NaN         NaN         NaN         NaN
# 96          28385         NaN         NaN         NaN         NaN
# 97          30013         NaN         NaN         NaN         NaN
# 98          31449         NaN         NaN         NaN         NaN
# 99          33515         NaN         NaN         NaN         NaN
#
#     Unnamed: 10  Unnamed: 11  Unnamed: 12 Unnamed: 13
# 0           NaN          NaN          NaN         NaN
# 1           NaN          NaN          NaN         NaN
# 2           NaN          NaN          NaN         NaN
# 3           NaN          NaN          NaN         NaN
# 4           NaN          NaN          NaN         NaN
# ..          ...          ...          ...         ...
# 95          NaN          NaN          NaN         NaN
# 96          NaN          NaN          NaN         NaN
# 97          NaN          NaN          NaN         NaN
# 98          NaN          NaN          NaN         NaN
# 99          NaN          NaN          NaN         NaN
#
# [100 rows x 14 columns]

# %%
df.describe()
# Out:
#        Unnamed: 1  cummlative cases       Death       Recoverd   \
# count   962.00000        962.000000   962.000000     962.000000
# mean    481.50000     478780.059252  6612.783784  460802.072765
# std     277.84978     236853.722583  2976.812289  238176.878706
# min       1.00000          1.000000     0.000000       0.000000
# 25%     241.25000     346581.500000  5368.000000  333106.000000
# 50%     481.50000     482612.000000  7767.500000  463630.000000
# 75%     721.75000     741026.750000  8986.750000  715033.500000
# max     962.00000     819811.000000  9390.000000  806237.000000
#
#        Active cases   Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# count     962.000000         0.0         0.0         0.0         0.0
# mean    11365.202703         NaN         NaN         NaN         NaN
# std     13141.084632         NaN         NaN         NaN         NaN
# min         1.000000         NaN         NaN         NaN         NaN
# 25%      3043.500000         NaN         NaN         NaN         NaN
# 50%      6828.000000         NaN         NaN         NaN         NaN
# 75%     11163.000000         NaN         NaN         NaN         NaN
# max     63026.000000         NaN         NaN         NaN         NaN
#
#        Unnamed: 10  Unnamed: 11  Unnamed: 12
# count          0.0          0.0          0.0
# mean           NaN          NaN          NaN
# std            NaN          NaN          NaN
# min            NaN          NaN          NaN
# 25%            NaN          NaN          NaN
# 50%            NaN          NaN          NaN
# 75%            NaN          NaN          NaN
# max            NaN          NaN          NaN

# %%
df.shape
# Out:
# (962, 14)

# %%
df = df.drop(columns=['Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13'])

# %%
df
# Out:
#            date  Unnamed: 1  cummlative cases  Death   Recoverd   \
# 0    02/03/2020           1                 1       0          0
# 1    03/03/2020           2                 1       0          0
# 2    04/03/2020           3                 2       0          0
# 3    05/03/2020           4                 5       0          0
# 4    06/03/2020           5                 5       0          0
# ..          ...         ...               ...     ...        ...
# 957  15/10/2022         958            818837    9381     805463
# 958  16/10/2022         959            819083    9383     805670
# 959  17/10/2022         960            819323    9384     805851
# 960  18/10/2022         961            819570    9387     806046
# 961  19/10/2022         962            819811    9390     806237
#
#      Active cases
# 0                1
# 1                1
# 2                2
# 3                5
# 4                5
# ..             ...
# 957           3993
# 958           4030
# 959           4088
# 960           4137
# 961           4184
#
# [962 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['date', 'Unnamed: 1', 'cummlative cases', 'Death ', 'Recoverd ',
#        'Active cases '],
#       dtype='object')

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 957    False
# 958    False
# 959    False
# 960    False
# 961    False
# Length: 962, dtype: bool

# %%
sns.boxplot(data=df)
# Out:
# <Axes: >

# %%
sns.pairplot(data=df)

# %%
X = df[['Death ','Recoverd ','cummlative cases']]
y = df['Active cases ']

# %%
X.isnull().sum()
# Out:
# Death               0
# Recoverd            0
# cummlative cases    0
# dtype: int64

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test) 
models = [LogisticRegression(max_iter=1000), RandomForestClassifier(), KNeighborsClassifier(),
          DecisionTreeClassifier(), SVC()]
model_names = ['Logistic Regression', 'Random Forest', 'KNN', 'Decision Tree', 'SVC']
model_scores = []

# Training models and evaluating accuracy
for model, model_name in zip(models, model_names):
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    model_scores.append((model_name, accuracy))

# Sorting models by accuracy
sorted_models = sorted(model_scores, key=lambda x: x[1], reverse=True)

# Displaying results
for model in sorted_models:
    print(f"Accuracy score: {model[0]}: {model[1]:.2f}")
# Out:
# C:\Users\HP\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Accuracy score: Random Forest: 0.01
# Accuracy score: Decision Tree: 0.01
# Accuracy score: Logistic Regression: 0.00
# Accuracy score: KNN: 0.00
# Accuracy score: SVC: 0.00
